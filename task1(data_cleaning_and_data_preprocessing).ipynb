# %% [markdown]
# <a href="https://colab.research.google.com/github/Anoop7485/Anoop/blob/main/task1(data_cleaning_and_data_preprocessing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MEDICAL APPOINTMENT NO SHOWS**

# %% [markdown]
# DATA CLEANNG AND PROCESSING

# %%
import pandas as pd

# %%
#IMPORTING DATASET USING PATH
medical_data=pd.read_csv('/Medical Appointment No shows.csv')

# %%
#TO GET DETAILS OF FIRST FIVE PATIENTS
medical_data.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
#TO GET DETAILS OF LAST FIVE PATIENTS
medical_data.tail()
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 43186  2.314676e+13        5691982      M  2016-05-12T14:07:24Z
# 43187  8.331295e+10        5690248      M  2016-05-12T09:43:46Z
# 43188  9.531746e+13        5662361      M  2016-05-05T08:27:05Z
# 43189  3.257342e+13        5636567      M  2016-04-28T15:38:16Z
# 43190  8.331295e+10        5692286      M  2016-05-12T14:52:57Z
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 43186  2016-05-19T00:00:00Z    5       PRAIA DO SUÁ            0
# 43187  2016-05-12T00:00:00Z    9       PRAIA DO SUÁ            0
# 43188  2016-05-19T00:00:00Z    8       PRAIA DO SUÁ            1
# 43189  2016-05-05T00:00:00Z    7  JESUS DE NAZARETH            0
# 43190  2016-05-19T00:00:00Z    9       PRAIA DO SUÁ            0
#
#        Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show
# 43186             0         0           0        0             0     Yes
# ...

# %%
#WE DETERMINE NO OF  ROWS AND COLUMNS IN DATASET
medical_data.shape
# Out:
# (43191, 14)

# %%
#getting some info about data
medical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43191 entries, 0 to 43190
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientId       43191 non-null  float64
#  1   AppointmentID   43191 non-null  int64
#  2   Gender          43191 non-null  object
#  3   ScheduledDay    43191 non-null  object
#  4   AppointmentDay  43191 non-null  object
#  5   Age             43191 non-null  int64
#  6   Neighbourhood   43191 non-null  object
#  7   Scholarship     43191 non-null  int64
#  8   Hipertension    43191 non-null  int64
#  9   Diabetes        43191 non-null  int64
#  10  Alcoholism      43191 non-null  int64
#  11  Handcap         43191 non-null  int64
#  12  SMS_received    43191 non-null  int64
#  13  No-show         43191 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 4.6+ MB

# %%
#checking for missing values
medical_data.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
#statistical measures about data
medical_data.describe()
# Out:
#           PatientId  AppointmentID           Age   Scholarship  Hipertension  \
# count  4.319100e+04   4.319100e+04  43191.000000  43191.000000  43191.000000
# mean   1.488369e+14   5.657578e+06     36.209673      0.100229      0.193212
# std    2.579998e+14   6.135413e+04     22.628060      0.300309      0.394822
# min    9.377953e+04   5.030230e+06      0.000000      0.000000      0.000000
# 25%    4.228639e+12   5.631014e+06     17.000000      0.000000      0.000000
# 50%    3.122576e+13   5.665184e+06     36.000000      0.000000      0.000000
# 75%    9.447638e+13   5.699944e+06     54.000000      0.000000      0.000000
# max    9.999465e+14   5.754966e+06     98.000000      1.000000      1.000000
#
#            Diabetes    Alcoholism       Handcap  SMS_received
# count  43191.000000  43191.000000  43191.000000   43191.00000
# mean       0.066843      0.038457      0.021949       0.30342
# std        0.249752      0.192299      0.159241       0.45974
# ...

# %%
#removing duplicates in dataset
medical_data.drop_duplicates()
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 0      2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1      5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2      4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3      8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4      8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...             ...            ...    ...                   ...
# 43186  2.314676e+13        5691982      M  2016-05-12T14:07:24Z
# 43187  8.331295e+10        5690248      M  2016-05-12T09:43:46Z
# 43188  9.531746e+13        5662361      M  2016-05-05T08:27:05Z
# 43189  3.257342e+13        5636567      M  2016-04-28T15:38:16Z
# 43190  8.331295e+10        5692286      M  2016-05-12T14:52:57Z
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
medical_data = medical_data[medical_data['Age'] >= 0]

# %%
#converting scheduleday and appointmentday into numbers which are in strings
medical_data['ScheduledDay'] = pd.to_datetime(medical_data['ScheduledDay'])
medical_data['AppointmentDay'] = pd.to_datetime(medical_data['AppointmentDay'])

# %%
#checking first five patients whether scheduleday and appointmentday is convert from strings or not
medical_data.head()
# Out:
#       PatientId  AppointmentID Gender              ScheduledDay  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0             1         0           0        0             0      No
# ...
